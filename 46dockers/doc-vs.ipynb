# %% [markdown]
# # 🐳 **Docker Image vs Container**
#
# ---
#
# ### 👋 **Hello guys!**
#
# Welcome back!
# In this video, we’re going to discuss about **<span style="color:red;">Docker Image</span>** and **<span style="color:red;">Container</span>** — two of the most fundamental concepts in Docker.
#
# ---
#
# ## 🧩 **Starting with the Concept**
#
# Let’s say this is your entire **application**,
# and it has **a lot of dependencies** and **configurations**.
#
# To **convert this application into a container**,
# we need to **containerize** (or **dockerize**) the entire application.
#
# ---
#
# ## 🧱 **Understanding Layers of Images**
#
# In Docker, we don’t build containers directly.
# We first build them using **layers of images** 🧩
#
# Let’s see what that means.
#
# ---
#
# ### 🔹 Example: Layers of a Docker Image
#
# 1. **Base Layer:**
#    - Could be a lightweight **Linux** image (e.g., Ubuntu, Alpine).
#    - Forms the **foundation** of your container.
#
# 2. **Database Layer:**
#    - Add a database image (like **MongoDB** or **MySQL**).
#    - Example: `mongo:latest` or `mysql:8.0`
#
# 3. **Python Layer:**
#    - Install a specific Python version (e.g., **Python 3.7**).
#    - `python:3.7-slim`
#
# 4. **Library Layer:**
#    - Install tools like **Anaconda**, **NumPy**, **Pandas**, etc.
#
# 5. **Application Layer:**
#    - Add your project files, code, and configurations.
#
# So overall,
# > 🧩 **A container = multiple layers of images combined together.**
#
# ---
#
# ## 📦 **Docker Image**
#
# > A **Docker Image** is a **read-only template** that contains the **instructions** to create a container.
#
# - Think of it as a **blueprint** or **package** that defines your environment.
# - It includes:
#   - Base OS
#   - Application dependencies
#   - Configurations
#   - Commands to run
#
# ---
#
# ## 🧰 **Docker Container**
#
# > A **Container** is a **runtime instance** of a **Docker Image**.
#
# Once you **run an image**, Docker:
# 1. Creates an **isolated environment**.
# 2. Installs all dependencies.
# 3. Runs your **application** inside that environment.
#
# So, the **image** is like a **recipe**,
# and the **container** is the **dish prepared using that recipe** 🍲
#
# ---
#
# ## 🔍 **Difference Between Docker Image and Container**
#
# | **Aspect** | **Docker Image** 🧱 | **Docker Container** 🚀 |
# |-------------|--------------------|-------------------------|
# | **Definition** | A **package/artifact** that includes dependencies and configurations | A **runtime instance** created from an image |
# | **State** | Static (read-only) | Dynamic (runs and changes) |
# | **Purpose** | Blueprint for creating containers | Executes the application |
# | **Creation** | Built using Dockerfile | Created when the image is run |
# | **Storage** | Stored in Docker Registry (e.g., Docker Hub) | Exists temporarily while running |
# | **Example** | `python:3.8`, `ubuntu:latest` | `container_id` running that image |
# | **Dependency Installation** | Contains all dependencies pre-packaged | Uses dependencies already in the image |
# | **Portability** | Can be shared/moved easily | Runs only on a specific host until stopped |
#
# ---
#
# ## ⚙️ **Step-by-Step Flow**

# %% [markdown]
# Application Code
#
# ↓
#
# Dockerfile
#
# ↓
#
# Docker Build → Creates → 🧱 Docker Image
#
# ↓
#
# Docker Run → Creates → 🚀 Container (runtime environment)

# %% [markdown]
# ---
#
# ## 💡 **Analogy**
#
# Think of:
# - 🧱 **Image → Blueprint**
# - 🚀 **Container → Actual running instance**
#
# Just like a **class and object** in OOP:
# - The **class** defines properties and methods (like an image)
# - The **object** is the instance created from the class (like a container)
#
# ---
#
# ## 🔄 **Relationship Between Image & Container**
#
# - You can create **many containers** from **one image**
# - Each container is **isolated**, even if built from the same image
# - When you delete a container, the **image remains intact**
#
# ---
#
# ## ⚖️ **Key Takeaway**
#
# - 🧩 **Docker Image** = Blueprint / Package / Artifact
# - 🧱 **Container** = Running Environment / Instance of the Image
# - 📦 Both together make Docker **lightweight**, **portable**, and **efficient**
#
# ---
#
# ## 🌍 **Coming Up Next**
#
# In the next lesson, we’ll discuss:
#
# - 🖥️ **Difference between Containers and Virtual Machines (VMs)**
# - ⚙️ **Why Docker Images are smaller and faster**
# - 💻 **Practical examples: creating and running images**
#
# ---
#
# ✨ **Pro Tip:**
# > When in doubt — “Image is the recipe, Container is the dish.” 🍲
#
# ---
#
# 🌟 **See you all in the next video!**

# %% [markdown]
# # 🐳 **Docker vs Virtual Machine (VM)**
#
# ---
#
# ## 🎯 **Introduction**
#
# Before we go deeper into Docker,
# we need to clearly understand the **difference between Docker and Virtual Machines (VMs)**.
#
# Both **Docker** and **VMs** perform **virtualization**,
# but *they do it in completely different ways!* ⚙️
#
# ---
#
# ## 🧠 **Understanding OS Architecture**
#
# Let’s first look at how a typical **Operating System (OS)** is structured:

# %% [markdown]
# +----------------------------+
#
# | Application Layer | ← Layer 2
#
# +----------------------------+
#
# | OS Kernel (e.g., Linux) | ← Layer 1
#
# +----------------------------+
#
# | Hardware (CPU, RAM, Disk) |
#
# +----------------------------+

# %% [markdown]
# ### 🔸 Components:
# - **Hardware** → Physical machine (CPU, RAM, etc.)
# - **OS Kernel** → Communicates with hardware
# - **Application Layer** → Where user apps and UI reside
#
# ---
#
# ## ⚙️ **Virtualization Approach**
#
# ### 🐳 **Docker**
# - **Docker virtualizes only the Application Layer**.
# - Docker containers **share the host OS kernel**.
# - The Docker image communicates directly with the **host kernel**.

# %% [markdown]
# +-----------------------------------+
#
# | Application Layer (Docker Images) |
#
# +-----------------------------------+
#
# | Host OS Kernel (shared) |
#
# +-----------------------------------+
#
# | Hardware |
#
# +-----------------------------------+

# %% [markdown]
# ✅ **Lightweight**, **faster**, and **efficient**
#
# ---
#
# ### 💻 **Virtual Machine (VM)**
# - VMs **virtualize both the Application Layer and the OS Kernel**.
# - Each VM contains its **own OS kernel** (called Guest OS).
# - Runs on top of a **hypervisor** (like VirtualBox, VMware, etc.)

# %% [markdown]
# +-----------------------------------+
#
# | Guest Application Layer (VM) |
#
# +-----------------------------------+
#
# | Guest OS Kernel |
#
# +-----------------------------------+
#
# | Hypervisor |
#
# +-----------------------------------+
#
# | Host OS Kernel |
#
# +-----------------------------------+
#
# | Hardware |
#
# +-----------------------------------+

# %% [markdown]
# ❌ **Heavier**, **slower**, and **more resource-intensive**
#
# ---
#
# ## ⚔️ **Docker vs Virtual Machine — Comparison Table**
#
# | **Aspect** | **🐳 Docker** | **💻 Virtual Machine (VM)** |
# |-------------|---------------|-----------------------------|
# | **Virtualization Level** | Virtualizes only the **Application Layer** | Virtualizes **Application + OS Kernel** |
# | **OS Kernel** | Shares **host kernel** | Has its **own kernel** |
# | **Size** | 🟢 Smaller (MBs) | 🔴 Larger (GBs) |
# | **Startup Time** | 🟢 Very fast (seconds) | 🔴 Slow (minutes) |
# | **Performance** | 🟢 Near native performance | 🔴 Slower due to kernel duplication |
# | **Resource Usage** | 🟢 Lightweight | 🔴 Heavy (dedicated RAM, Disk space) |
# | **Compatibility** | ⚠️ May face OS compatibility issues | 🟢 No compatibility issues |
# | **Isolation** | Moderate isolation | Strong isolation (complete OS separation) |
# | **Use Case** | Ideal for **microservices**, **containers**, **CI/CD** | Ideal for **full OS simulation**, **legacy apps** |
#
# ---
#
# ## 🔍 **Key Observations**
#
# ### 🧩 1. **Image Size**
# - **Docker images** are **smaller** because they **reuse the host kernel**.
#   → Usually **megabytes (MBs)** in size.
# - **VMs** include their own OS kernel and system files.
#   → Usually **gigabytes (GBs)** in size.
#
# ---
#
# ### ⚡ 2. **Startup Speed**
# - **Docker containers** start and run **much faster** 🚀
#   → They just initialize the app layer.
# - **VMs** take **longer** ⏳
#   → Because a full OS boot is required.
#
# ---
#
# ### 🔄 3. **Compatibility**
# - **VMs**:
#   ✅ Can run **any OS on any OS** (e.g., Linux VM on Windows).
# - **Docker**:
#   ⚠️ Can only run containers **compatible with the host kernel**.
#   Example:
#   - A **Linux Docker image** cannot run directly on **Windows 7**.
#   - But it **can run on Windows 10+** (because of **WSL 2** integration).
#
# ---
#
# ## 💬 **Analogy**
#
# | **Concept** | **Docker** | **Virtual Machine** |
# |--------------|-------------|---------------------|
# | **Analogy** | Apartment in a shared building 🏢 | Individual house 🏠 |
# | **Kernel Sharing** | Shared with others | Private for each |
# | **Speed** | Instant (like opening a door) | Slow (like building a new house) |
# | **Memory Usage** | Low | High |
#
# ---
#
# ## 🧠 **Summary**
#
# | **Feature** | **Docker** | **Virtual Machine** |
# |--------------|-------------|---------------------|
# | **Virtualization Type** | OS-Level | Hardware-Level |
# | **Boot Time** | Seconds | Minutes |
# | **Size** | MBs | GBs |
# | **Performance** | Near-native | Slower |
# | **Portability** | High | Medium |
# | **Security** | Moderate | Strong |
# | **Use Case** | Cloud apps, DevOps, Microservices | Full OS environments, Legacy apps |
#
# ---
#
# ## 🏁 **Key Takeaways**
#
# - 🟢 **Docker** → Virtualizes only the **Application Layer**
# - 🟢 **VMs** → Virtualize both **Application Layer** and **OS Kernel**
# - ⚡ **Docker is lightweight and fast**, while **VMs are heavier and slower**
# - ⚠️ **Compatibility**: Docker may face kernel compatibility issues
# - 💪 **VMs** are better for **complete OS isolation**
#
# ---
#
# ## 🔧 **Next Steps**
#
# In the next video, we’ll:
# - Install **Docker** on your system 🧑‍💻
# - Learn to **run containers**
# - Build and **dockerize real applications**
#
# ---
#
# ✨ **Pro Tip:**
# > 🧠 Think of **Docker as a shared workspace** and **VM as a separate office**.
# > Both get the job done — one faster, one more private.
#
# ---
#
# 💬 **Thank you guys!**
# See you all in the next video 👋

# %% [markdown]
# # 🐳 Docker Tutorial — Creating, Running & Pushing Docker Images
#
# ---
#
# ## 🔹 Recap
#
# Till now, we have seen how to:
#
# - 🧩 **Pull a Docker image** from **Docker Hub Repository**
# - 🚀 **Run that image as a container** on our host machine
# - ⚙️ Use important Docker commands like:
#   - `docker ps`
#   - `docker images`
#   - `docker pull`
#   - `docker run`
#
# > 💡 **Tip:**
# > To check how many containers are running:
# > ```bash
# > docker ps
# > ```
# > To list available images:
# > ```bash
# > docker images
# > ```
#
# ---
#
# ## 🎯 Objective
#
# Now, we’ll **create our own Docker image**, **run it as a container**, and **push it to Docker Hub**.
# The flow will be:
#
# 1. Create a simple Flask application
# 2. Dockerize it
# 3. Build and run the image
# 4. Push the image to **Docker Hub**
#
# ---
#
# ## 🧠 Step 1: Simple Flask Application
#
# We have two files:

# %% [markdown]
# app.py
# requirements.txt

# %% [markdown]
# ### **📜 app.py**
# ```python
# from flask import Flask
# app = Flask(__name__)
#
# @app.route('/')
# def hello():
#     return "Hello World"
#
# if __name__ == "__main__":
#     app.run(host="0.0.0.0", port=500
