# %% [markdown]
# ---
#
# ````markdown
# # 🧩 Git & GitHub — Part 2: Staging, Reset, Diff, and Branching
#
# Welcome back, everyone! 👋
# In this section, we’ll continue our journey with **Git and GitHub**, diving deeper into commands like
# <span style="color:orange">`git reset`</span>, <span style="color:orange">`git diff`</span>, and branching strategies such as
# <span style="color:lightgreen">branch creation</span>, <span style="color:lightblue">checkout</span>, and <span style="color:violet">merge</span>.
#
# ---
#
# ## 🎯 Recap from Previous Session
#
# Previously, we learned:
# - Installing **Git CLI** (for Windows, Mac, Linux)
# - Setting up global configuration
#   ```bash
#   git config --global user.name "Your Name"
#   git config --global user.email "your_email@example.com"
# ````
#
# * Using <span style="color:orange">`git init`</span>, <span style="color:orange">`git clone`</span>, and <span style="color:orange">`git status`</span>
# * Adding and committing files
#
# Now, let’s explore **staging**, **unstaging**, and **branching** — the real backbone of Git workflow. ⚙️
#
# ---
#
# ## 📘 Understanding `git status`
#
# The command:
#
# ```bash
# git status
# ```
#
# shows:
#
# * Modified files
# * Staged files (ready for commit)
# * Untracked files (new files not yet added to Git)
#
# Example:
#
# ```
# Untracked files:
#   new_document3.txt
# ```
#
# 💡 <span style="color:lightgreen">Note:</span>
# Untracked = Git sees the file but hasn’t started tracking its changes yet.
#
# ---
#
# ## 🧩 Adding Files to Staging Area
#
# Use:
#
# ```bash
# git add .
# ```
#
# or specify file name:
#
# ```bash
# git add new_document3.txt
# ```
#
# The dot (`.`) adds **all files** in the current folder to staging.
#
# ---
#
# ## 🔄 Unstaging Files: `git restore` & `git reset`
#
# Sometimes you might add files by mistake.
# You can **unstage** them using:
#
# ### 🟠 Method 1 — `git restore`
#
# ```bash
# git restore --staged new_document3.txt
# ```
#
# This removes the file from the staging area but keeps it locally.
#
# ---
#
# ### 🔵 Method 2 — `git reset`
#
# ```bash
# git reset new_document3.txt
# ```
#
# Performs a similar action — unstages the file, moving it back to untracked state.
#
# ---
#
# ## 🧠 Difference Between `restore` and `reset`
#
# | Command                       | Action               | Affects Working Directory     |
# | ----------------------------- | -------------------- | ----------------------------- |
# | `git restore --staged <file>` | Removes from staging | ❌ No                          |
# | `git reset <file>`            | Removes from staging | ✅ Sometimes (depends on mode) |
#
# 💡 Both are used to **unstage files**, but `restore` is newer and more explicit.
#
# ---
#
# ## 📊 Viewing Changes: `git diff` and `git diff --staged`
#
# ### 🟢 `git diff`
#
# Shows what has **changed but not yet staged**.
#
# ```bash
# git diff
# ```
#
# ### 🔵 `git diff --staged`
#
# Shows the **difference between the staged files** and the last commit.
#
# ```bash
# git diff --staged
# ```
#
# These commands are helpful before you commit — to ensure you’re pushing the right changes.
#
# ---
#
# ## 💾 Committing Files
#
# Once you’re confident:
#
# ```bash
# git commit -m "Added new_document3.txt file"
# ```
#
# Now check status:
#
# ```bash
# git status
# ```
#
# Output:
#
# ```
# On branch main
# nothing to commit, working tree clean
# ```
#
# Your changes are now part of the **local repository history**.
#
# ---
#
# ## ☁️ Pushing to GitHub
#
# After committing, push your changes:
#
# ```bash
# git push origin main
# ```
#
# ✅ The file `new_document3.txt` is now uploaded to GitHub.
#
# 💡 <span style="color:orange">Tip:</span>
# Each commit creates a **snapshot** (a permanent save point).
# It’s like a checkpoint in your game — you can always revert to it later.
#
# ---
#
# ## 🧩 Stage and Snapshot Concept
#
# When you run:
#
# ```bash
# git commit -m "message"
# ```
#
# You’re taking a **snapshot** of your project — this snapshot is stored in your local Git database.
# You can push this snapshot to your GitHub repo using `git push`.
#
# Think of it as:
#
# ```
# Working Directory → Staging → Local Repository → Remote Repository
# ```
#
# ---
#
# ## 🌿 Branching: Working in Teams
#
# In real-world projects, multiple developers work simultaneously.
# Each developer works on a **separate branch** derived from the main branch.
#
# ---
#
# ### 🟣 Checking Current Branch
#
# ```bash
# git branch
# ```
#
# Output:
#
# ```
# * main
# ```
#
# ---
#
# ### 🟠 Creating a New Branch
#
# ```bash
# git branch developer
# ```
#
# Now check branches:
#
# ```bash
# git branch
# ```
#
# Output:
#
# ```
# * main
#   developer
# ```
#
# ---
#
# ### 🟢 Switching Branches
#
# ```bash
# git checkout developer
# ```
#
# Output:
#
# ```
# Switched to branch 'developer'
# ```
#
# Now any changes or commits you make will stay **only** in the developer branch.
#
# ---
#
# ## 🧠 Why Use Branches?
#
# * To **work on features** or **fixes** independently.
# * To **avoid conflicts** in the main branch.
# * To **test** before merging changes.
#
# 💡 Always branch from the **main branch** before starting new work.
#
# ---
#
# ## ✏️ Commit in Developer Branch
#
# Now create a new file and commit it:
#
# ```bash
# echo "Developer work" > dev_file.txt
# git add .
# git commit -m "Added developer story work"
# ```
#
# Your file and commit exist only in the `developer` branch.
#
# ---
#
# ## 🔁 Merging Branches
#
# Once your work is tested and complete, merge it back into the main branch.
#
# ### Step 1: Switch to Main Branch
#
# ```bash
# git checkout main
# ```
#
# ### Step 2: Merge Developer Branch
#
# ```bash
# git merge developer
# ```
#
# Output example:
#
# ```
# Updating a1b2c3d..e4f5g6h
# Fast-forward
#  dev_file.txt | 1 +
# ```
#
# 🎉 Your developer branch is now merged into `main`.
#
# ---
#
# ## ☁️ Push the Merged Changes
#
# Finally, push your updated main branch to GitHub:
#
# ```bash
# git push origin main
# ```
#
# Now refresh GitHub — you’ll see all merged files.
#
# ---
#
# ## 🧭 Git Logs — Viewing Commit History
#
# View all commits:
#
# ```bash
# git log
# ```
#
# To exit the log view, press **Q**.
#
# ---
#
# ### 🔍 View Limited Commits
#
# ```bash
# git log -p -3
# ```
#
# Shows last 3 commits with details.
#
# Example output:
#
# ```
# commit 8cfa9b1 Added developer story work
# commit 3e2d1a4 Added new_document3.txt
# commit 1b2a3c5 Initial commit
# ```
#
# ---
#
# ## 🧩 Summary Table
#
# | Concept         | Command                         | Description        |
# | --------------- | ------------------------------- | ------------------ |
# | Check status    | `git status`                    | Show file states   |
# | Add file        | `git add .`                     | Move to staging    |
# | Unstage file    | `git restore --staged <file>`   | Undo staging       |
# | View difference | `git diff`, `git diff --staged` | Compare changes    |
# | Commit changes  | `git commit -m "msg"`           | Snapshot locally   |
# | Push changes    | `git push origin main`          | Update remote repo |
# | Create branch   | `git branch <name>`             | Make new branch    |
# | Switch branch   | `git checkout <name>`           | Move to branch     |
# | Merge branches  | `git merge <branch>`            | Combine code       |
# | View commits    | `git log`                       | History of commits |
#
# ---
#
# ## 🚀 What’s Next?
#
# In the next video, we’ll learn:
#
# * How to **push new branches** to GitHub
# * How to **create pull requests (PRs)**
# * How to **merge branches remotely**
#
# This will complete our Git collaboration workflow. 🌟
#
# ---
#
# <span style="color:lightgreen">✨ Summary:</span>
# We explored:
#
# * <span style="color:orange">Staging and unstaging</span> files
# * <span style="color:lightblue">Committing</span> snapshots
# * <span style="color:violet">Branching and merging</span>
# * <span style="color:lightgreen">Using logs and diffs</span>
#
#
# ```
#
# ---
#
# ```
