# %% [markdown]
# ✅ **Features included:**
#
# * 🎨 Highlighted color-coded text (`<span style="color:...">`) for key concepts.
# * 🧠 Proper Markdown headings for each topic.
# * 💻 Code blocks for all commands and examples.
# * 📘 Ready to paste directly into a `.md` file in VS Code for beautiful rendering.
# * 💡 Structured like a mini Git course — easy to study and navigate.
#
# ---
#
# ````markdown
# # 🧩 Git & GitHub — Complete Beginner’s Tutorial
#
# Welcome to this **series of videos** where we’ll understand <span style="color:orange">Git</span> — one of the most widely used version control systems.
# In this series, we’ll learn about **best practices** for committing and managing code in repositories, especially when working in **IT teams** with multiple developers — frontend, backend, AI, and others.
#
# ---
#
# ## 🎯 Objective
#
# When many developers are working on the same project, we must ensure:
# - Everyone’s code is **in sync**
# - **No conflicts** occur in the main repository
# - **Best commit methodologies** are followed
#
# We’ll explore how to:
# - Create repositories on **GitHub**
# - Use **Git CLI** for commits and pushes
# - Follow professional Git workflows
#
# ---
#
# ## 🧱 What Is Git?
#
# > <span style="color:lightgreen">Git</span> is a **free and open-source distributed version control system (VCS)** responsible for everything GitHub-related that happens locally on your computer.
#
# It allows you to:
# - Track changes to your codebase
# - Commit locally
# - Push changes to remote repositories
#
# 💡 <span style="color:orange">In short:</span>
# Git = Local version control
# GitHub = Cloud hosting for Git repositories
#
# ---
#
# ## ⚙️ Step 1: Creating a GitHub Repository
#
# 1. Go to your **GitHub account**
# 2. Click on **New Repository**
# 3. Name it, e.g. `git-tutorials`
# 4. Don’t add anything yet:
#    - ❌ No README
#    - ❌ No `.gitignore`
#    - ❌ No License
# 5. Click **Create Repository**
#
# ---
#
# ## 🧩 Step 2: Installing Git CLI
#
# If Git is not installed:
#
# - Go to [https://git-scm.com/downloads](https://git-scm.com/downloads)
# - Choose your OS:
#   - macOS 🍎
#   - Windows 🪟
#   - Linux 🐧
# - Download and **install with default settings**
#
# ### ✅ Verify Installation
#
# Open Command Prompt or Terminal:
#
# ```bash
# git --version
# ````
#
# If you see output like:
#
# ```
# git version 2.xx.x
# ```
#
# Then Git is successfully installed. 🎉
#
# ---
#
# ## 📁 Step 3: Initialize a Local Repository
#
# Now let’s create some files locally and commit them to GitHub.
#
# Go to your working directory (e.g., G drive):
#
# ```bash
# cd G:\
# mkdir git_tutorials
# cd git_tutorials
# git init
# ```
#
# This initializes an **empty Git repository**.
#
# It also creates a hidden folder:
#
# ```
# .git/
# ```
#
# 🧠 <span style="color:lightgreen">Note:</span>
# This `.git` folder stores all configuration, history, and commit info — **never commit this folder**.
#
# ---
#
# ## ⚙️ Step 4: Set Global Configuration
#
# You must configure your identity once for Git to recognize you when committing code.
#
# ```bash
# git config --global user.name "Your Name"
# git config --global user.email "your_email@example.com"
# ```
#
# Check your configuration:
#
# ```bash
# git config --global user.name
# git config --global user.email
# ```
#
# 💡 <span style="color:orange">Tip:</span>
# Use the same email that’s linked to your GitHub account — it helps authenticate and track commits.
#
# ---
#
# ## 📘 Step 5: Create Your First File
#
# Create a simple file named `README.md`.
#
# ```bash
# echo "# Git Tutorial" > README.md
# ```
#
# Now check repository status:
#
# ```bash
# git status
# ```
#
# Output example:
#
# ```
# No commits yet
# Untracked files:
#   README.md
# ```
#
# 🧠 “Untracked” means Git sees the file but is **not tracking changes yet.**
#
# ---
#
# ## 🧩 Step 6: Add Files to Staging Area
#
# Add the file to staging (tracked files list):
#
# ```bash
# git add README.md
# ```
#
# Now check again:
#
# ```bash
# git status
# ```
#
# Output:
#
# ```
# Changes to be committed:
#   new file: README.md
# ```
#
# ✅ This means your file is ready to be committed to the repository.
#
# ---
#
# ## 💾 Step 7: Commit Your Changes
#
# Commit the staged files with a descriptive message:
#
# ```bash
# git commit -m "First commit"
# ```
#
# Now your changes are stored locally (in Git history), not yet on GitHub.
#
# Check status:
#
# ```bash
# git status
# ```
#
# Output:
#
# ```
# On branch master
# nothing to commit, working tree clean
# ```
#
# ---
#
# ## 🌿 Step 8: Rename Branch (Optional)
#
# By default, Git creates a branch called `master`.
# Let’s rename it to `main` for standardization:
#
# ```bash
# git branch -M main
# ```
#
# Check branches:
#
# ```bash
# git branch
# ```
#
# Output:
#
# ```
# * main
# ```
#
# ---
#
# ## 🌐 Step 9: Connect Local Repo to GitHub
#
# Copy your GitHub repository’s **HTTPS URL**, e.g.:
#
# ```
# https://github.com/username/git-tutorials.git
# ```
#
# Then connect it as a remote origin:
#
# ```bash
# git remote add origin https://github.com/username/git-tutorials.git
# ```
#
# Verify connection:
#
# ```bash
# git remote -v
# ```
#
# Output:
#
# ```
# origin  https://github.com/username/git-tutorials.git (fetch)
# origin  https://github.com/username/git-tutorials.git (push)
# ```
#
# ---
#
# ## ☁️ Step 10: Push Code to GitHub
#
# Push your local commits to the remote repository:
#
# ```bash
# git push -u origin main
# ```
#
# Output example:
#
# ```
# Enumerating objects: 3, done.
# Writing objects: 100% (3/3), done.
# ```
#
# Now refresh your GitHub repo — you’ll see your `README.md` file there. 🎉
#
# ---
#
# ## ✏️ Step 11: Modify and Track Changes
#
# Let’s modify the `README.md` file:
#
# ```
# # Git Tutorial
# Please subscribe to this channel.
# ```
#
# Check changes:
#
# ```bash
# git status
# ```
#
# Output:
#
# ```
# modified: README.md
# ```
#
# If changes are correct:
#
# ```bash
# git add .
# git commit -m "Updated README with subscribe message"
# git push origin main
# ```
#
# If you made a mistake:
#
# ```bash
# git restore README.md
# ```
#
# This reverts to the last committed version. 🔄
#
# ---
#
# ## 📂 Step 12: Adding Multiple Files
#
# Create a new file:
#
# ```bash
# echo "This is a test file." > text1.txt
# ```
#
# Now check status:
#
# ```bash
# git status
# ```
#
# Output:
#
# ```
# Untracked files:
#   text1.txt
# ```
#
# Add all changes at once:
#
# ```bash
# git add .
# ```
#
# Commit:
#
# ```bash
# git commit -m "Added text1.txt and updated README"
# git push origin main
# ```
#
# Now both files will be visible in GitHub.
#
# ---
#
# ## 🧠 Understanding Git Workflow
#
# | Stage     | Command      | Purpose                     |
# | --------- | ------------ | --------------------------- |
# | Untracked | `git status` | Shows new or modified files |
# | Staging   | `git add`    | Prepares files for commit   |
# | Commit    | `git commit` | Saves snapshot locally      |
# | Push      | `git push`   | Sends commits to GitHub     |
#
# ---
#
# ## 🌀 Step 13: Cloning an Existing Repository
#
# If you want to download (clone) an existing repository:
#
# ```bash
# git clone https://github.com/username/git-tutorials.git
# ```
#
# This creates a local copy.
#
# To make new changes:
#
# ```bash
# cd git-tutorials
# echo "New file" > text2.txt
# git add .
# git commit -m "Added text2.txt"
# git push origin main
# ```
#
# ---
#
# ## ⚡ Step 14: Authentication
#
# The first time you push, Git may ask for:
#
# * **Username (GitHub username)**
# * **Password or Personal Access Token (PAT)**
#
# 🔐 <span style="color:red">Important:</span>
# GitHub no longer allows direct password authentication —
# use a **Personal Access Token (PAT)** instead.
#
# ---
#
# ## 🧩 Step 15: Summary
#
# | Step | Description           | Command                                      |
# | ---- | --------------------- | -------------------------------------------- |
# | 1    | Initialize repository | `git init`                                   |
# | 2    | Set user config       | `git config --global user.name / user.email` |
# | 3    | Add files             | `git add .`                                  |
# | 4    | Commit changes        | `git commit -m "Message"`                    |
# | 5    | Rename branch         | `git branch -M main`                         |
# | 6    | Connect remote repo   | `git remote add origin URL`                  |
# | 7    | Push changes          | `git push -u origin main`                    |
# | 8    | Clone repo            | `git clone URL`                              |
#
# ---
#
# ## 🔮 Next Steps
#
# In upcoming sections, we’ll learn:
#
# * <span style="color:orange">Branching</span> — creating separate work areas
# * <span style="color:lightgreen">Merging</span> — combining branches
# * <span style="color:skyblue">Reverting</span> — undoing changes safely
# * <span style="color:violet">Pull Requests</span> — collaborating on teams
#
# ---
#
# <span style="color:lightgreen">✨ Congratulations!</span>
